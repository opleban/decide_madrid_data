# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# LOAD IN ACTIVTY FROM FILE
proposal_file_path = 'proposals.csv'
comments_file_path = 'comments.csv'
# decide_proposals = []
# proposalReader = csv.DictReader(
#     open(proposal_file_path, newline=''), delimiter=';', quotechar='"')
# for proposal in proposalReader:
#     decide_proposals.append(proposal)

decide_proposals = pd.read_csv(proposal_file_path, sep=";", parse_dates=['created_at', 'retired_at'])
decide_comments = pd.read_csv(comments_file_path, sep=";")

# %%
print("There are", len(decide_proposals), "proposals")
print("There are", len(decide_comments), "comments")
# Out:
# There are 22994 proposals
# There are 123750 comments

# %%
REPLACE_NO_SPACE = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])")
REPLACE_WITH_SPACE = re.compile("(<br\s*/><br\s*/>)|(\-)|(\/)|(<p>)|<\s*p>|\r|\n")

# def preprocess_descriptions(proposals):
#     for proposal in proposals:
#             proposal['clean_description'] = REPLACE_NO_SPACE.sub("", proposal['description'].lower())
#             proposal['clean_description'] = REPLACE_WITH_SPACE.sub(" ", proposal['clean_description'])
#             proposal['clean_description'] = proposal['clean_description'].strip()
#     return proposals

def preprocess_description(df, description_column):
    df['clean_description'] = (
        df[description_column].replace(REPLACE_NO_SPACE, '')
        .replace(REPLACE_WITH_SPACE, ' ')
        .str.lower()
        .str.strip()
    )
    return df

decide_proposals = preprocess_description(decide_proposals, 'description')

# %%
decide_proposals.head()
# Out:
#    id                                              title  \
# 0   1   Hacer las calles del centro de Madrid peatonales
# 1   2   Crear una zona cercada para perros en Las Tablas
# 2   3                          Metro nuevo en la línea 1
# 3   4                           Un madrileño un árbol...
# 4   5  Uso artístico y de promoción del  Arco de la V...
#
#                                          description  \
# 0                                                NaN
# 1  <p>En la zona norte de Madrid (Las Tablas, San...
# 2  <p>Buenos Días.</p>\r\n\r\n<p>Pienso que deber...
# 3  <p>Plantando un arbol por cada madrileño, cons...
# 4  <p>La acción debe ser realizada con elementos ...
#
#                                         external_url  cached_votes_up  \
# 0                                                NaN             2896
# 1                                                NaN              134
# 2                                                NaN               93
# 3  http://www.un.org/climatechange/es/blog/2014/0...             2849
# 4                                                NaN               49
#
#    comments_count  hot_score  confidence_score          created_at  \
# 0             129  958888382            289600 2015-09-15 10:00:00
# 1              10  945606381             13400 2015-09-15 10:00:00
# 2               4  943994867              9300 2015-09-15 10:00:00
# 3              29  958850712            284900 2015-09-15 10:00:00
# 4               7  941326847              4900 2015-09-15 10:00:00
#
#                                              summary  \
# 0  Peatonalizar todas las calles del centro de Ma...
# 1  Crear un recinto cerrado donde poder soltar a ...
# 2                 Cambiar los metros de la línea 1.
# 3  Plantando un árbol por cada madrileño, consegu...
# 4  Mi idea es dar un uso al arco de la victoria d...
#
#                                      video_url  geozone_id retired_at  \
# 0                                          NaN         NaN        NaT
# 1                                          NaN         NaN        NaT
# 2                                          NaN         NaN        NaT
# 3  https://www.youtube.com/watch?v=ZzksgMrS_7o         NaN        NaT
# 4                                          NaN         NaN        NaT
#
#   retired_reason retired_explanation proceeding sub_proceeding  \
# 0            NaN                 NaN        NaN            NaN
# 1            NaN                 NaN        NaN            NaN
# 2            NaN                 NaN        NaN            NaN
# 3            NaN                 NaN        NaN            NaN
# 4            NaN                 NaN        NaN            NaN
#
#                                    clean_description
# 0                                                NaN
# 1  en la zona norte de madrid las tablas sanchina...
# 2  buenos días< p>     pienso que deberíamos camb...
# 3  plantando un arbol por cada madrileño consegui...
# 4  la acción debe ser realizada con elementos rec...

# %%
decide_proposals.describe()
decide_proposals.dtypes
# Out:
# id                              int64
# title                          object
# description                    object
# external_url                   object
# cached_votes_up                 int64
# comments_count                  int64
# hot_score                       int64
# confidence_score                int64
# created_at             datetime64[ns]
# summary                        object
# video_url                      object
# geozone_id                    float64
# retired_at             datetime64[ns]
# retired_reason                 object
# retired_explanation            object
# proceeding                     object
# sub_proceeding                 object
# clean_description              object
# dtype: object

# %%
decide_proposals['created_at_day'] = decide_proposals['created_at'].map(lambda x: x.strftime('%Y-%m-%d'))
decide_proposals['created_at_month'] = decide_proposals['created_at'].map(lambda x: x.strftime('%Y-%m'))
decide_proposals['created_at_year'] = decide_proposals['created_at'].map(lambda x: x.strftime('%Y'))
created_at_day_group = decide_proposals.groupby('created_at_day')
created_at_month_group = decide_proposals.groupby('created_at_month')
created_at_year_group = decide_proposals.groupby('created_at_year')
created_at_year_group.size().plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-05bfd823f4ec> in <module>()
#       5 created_at_month_group = decide_proposals.groupby('created_at_month')
#       6 created_at_year_group = decide_proposals.groupby('created_at_year')
# ----> 7 created_at_year_group.size().plot().gcf().autofmt_xdate()
#
# AttributeError: 'AxesSubplot' object has no attribute 'gcf'

# %%
import matplotlib.dates as mdates
created_at_month_group.size().plot(figsize=(20, 6))

# %%
created_at_day_group.size().plot(figsize=(20, 6))
